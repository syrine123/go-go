# %%
import csv
import pandas as pd

# %%
df_initial = pd.read_csv('df_new_initial.csv', sep=';')
df_initial.head(20)
# Out:
#      contactid  annee_mois  campagne                            campaign  \
# 0   6546762003         NaN      -1.0              Source URL non trouvée
# 1   6742433330         NaN     456.0  REC_Liens textes autopromotion 456
# 2   6856828837    201611.0     868.0               PAR_Onlin_Site _ECard
# 3   6754882186         NaN     300.0                   Intb_Banque_Autre
# 4   6289817192    201611.0     300.0                   Intb_Banque_Autre
# 5   6748699778         NaN     307.0                  REC_Onlin_MC_Googl
# 6   6856855432    201612.0     307.0                  REC_Onlin_MC_Googl
# 7   6821231675    201611.0     868.0               PAR_Onlin_Site _ECard
# 8   6747566365         NaN     868.0               PAR_Onlin_Site _ECard
# 9   6888675097    201611.0    1543.0            REC_Onlin_Parte_Bours_SP
# 10  6879474578    201611.0     300.0                   Intb_Banque_Autre
# 11  6821501450    201611.0     868.0               PAR_Onlin_Site _ECard
# ...

# %%
df_nouv_cible = pd.read_csv('Encours1moisApresDataDevenueClient.csv', sep='\t')
df_nouv_cible.head(20)
# Out:
#     SID_DIM_PERSONNE  ID_DIM_PERSONNE date_devenu_client  delai_transfo  \
# 0             909711       1529146396         29/10/2009             33
# 1            1013477       1660202716         12/02/2010              8
# 2            1299061       2049829768         07/12/2016           2147
# 3            1326577       2090633956         28/12/2016           2133
# 4            1654293       2622597285         09/09/2016           1588
# 5            1783238       2877945061         14/11/2012             24
# 6            1851371       3036283077         19/12/2016           1423
# 7            2237347       3842092286         17/03/2014             14
# 8            2313668       4043908346         06/06/2014              4
# 9            2475455       4411214692         07/11/2016            736
# 10           2645613       4806529764         14/10/2016            586
# 11           2647848       4813182747         24/11/2016            625
# ...

# %%
df_nouv_cible.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29606 entries, 0 to 29605
# Data columns (total 6 columns):
# SID_DIM_PERSONNE      29606 non-null int64
# ID_DIM_PERSONNE       29606 non-null int64
# date_devenu_client    29606 non-null object
# delai_transfo         29606 non-null int64
# ENCOURS               29606 non-null float64
# date_solde            29606 non-null object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 1.4+ MB

# %%
countTP=0
countSL=0
for ENCOURS in df_nouv_cible:
    row=0
    for row in df_nouv_cible[ENCOURS]:
        if row > 2000:
            #return 1
        df_nouv_cible[new_cible]=1
        elif row < 2000:
        df_nouv_cible[new_cible]=0
        #return 0

#print countTP, countSL
# Out:
#   File "<ipython-input-23-942e96d6be1e>", line 7
#     df_nouv_cible[new_cible]=1
#                 ^
# IndentationError: expected an indented block
